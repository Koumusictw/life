# %%
def x():
    fp = open("awa.txt", "w", encoding="utf-8")
    fp.write("                                                            "+"\n")
    fp.write("       ,=#~        .                                        "+"\n")
    fp.write("     ?  ~X?-      ...                                       "+"\n")
    fp.write("     ?.-*^^      .,~--.                      ,,             "+"\n")
    fp.write("   ,-=  ~^       .-.~~,,..                 ,,--             "+"\n")
    fp.write("     *^ ,?       ,,.,.~-,,,-,,,-******~-,,,-~~~             "+"\n")
    fp.write("     -?    .,^.  .,,,~-,,--,,,,,--~****~--~~~~-             "+"\n")
    fp.write("      .  ,.*^.    .~,,,,,,------,~--~***~*-,~~.             "+"\n")
    fp.write("           >-     ..,,,-~***~****-*~~^*~**~--               "+"\n")
    fp.write("           .,     .,-,,~*~*,~~**~***^-**~~~,                "+"\n")
    fp.write("         ?*      .,~--***~,,~~~~~~~~~-**-**~                "+"\n")
    fp.write("         -=,    .,-^~**>~^>^~,-~~*~-.,~*-***.               "+"\n")
    fp.write("       .-=X     ,-,^*~~........,,.~>=X?*~***,               "+"\n")
    fp.write("     -, ~,^=   ..-,,~-,.... .. .....,--=**^-                "+"\n")
    fp.write("       -^ .#,..-~,-,~~....,>===>>,....,~~*^,    ..          "+"\n")
    fp.write("       *.    .,,,,--^-...-^^^^>^=>....-~~~*~.  .,-,-.       "+"\n")
    fp.write("      .   >-,.,,,,~^^^^..-,^^^*^*~...,^^,~~- ..,,,,,--      "+"\n")
    fp.write("          ~?.,,,**^^^^^^...-.---....~^^^^-~~.  .,,,,,~-     "+"\n")
    fp.write("         .,#~~-~*^^^*^>^>**......-^^^^^^^--*~   .-,,,---    "+"\n")
    fp.write("        ,.--=-~~^**~**^>^,*^^*^^=>X^*^***^,~~.   -~-,,,~,   "+"\n")
    fp.write("       .,~**?*-~**^*^~*>,,,-,-,-~?#*^****^--*~,   -,,,,,-   "+"\n")
    fp.write("       ,*^^*-#.~,,-^,.,=-,,*=*^#X#=,,~**^*~,*^~.  -,,,,,~   "+"\n")
    fp.write("      -*~^**^*#,. .~...-?==#=>XX=,-,,,,,,**,*^*,   .,,,,~   "+"\n")
    fp.write("     ,,~~***~~.~.  ,,,,..-*^*,,...,.....--~-^**-.  ,,,,-^   "+"\n")
    fp.write("    .,-,~****,,~,.   -..,~~~*,...........--****~, .,,,--*   "+"\n")
    fp.write("     -.,~~**~,,*,,     .,,---............*-**~*~,  ,,,,--   "+"\n")
    fp.write("     , ,,*~~*-,-~.          ,,.........--~*~*-*-- ,,,,,-,   "+"\n")
    fp.write("     . .,-~~-, ,,~,.           . ......~*~~~~---  ,,,,,~.   "+"\n")
    fp.write("         ,-~,. .,.*^ ...          ....,,,--.. .  .,,,,-~    "+"\n")
    fp.write("            . , ,-*~^-^^^,,.  .         ,,.      ,,,,,~.    "+"\n")
    fp.write("           .   ..,.*~-*-~^^~-.,.     ....,      .,,,,~-     "+"\n")
    fp.write("           .   .,-.->~~~~>-,>*? ,    ,.,,-     .,,,,-~.     "+"\n")
    fp.write("           ,   ,,,,,,>*,,*-X.,~,,   ..  .-    ..,-~~~,      "+"\n")
    fp.write("            ...,,.- . .~~*~^,^ -.        ,. .,-~****,       "+"\n")
    fp.write("              -,,,,.., ..., -  -      .. ,~~***~***.        "+"\n")
    fp.write("              ,,--,- ,.  ,,  ..-      ,, .~*****^,          "+"\n")
    fp.write("              ..,,,,, ..  ,, .,.     ,,, ,,~^^^,            "+"\n")
    fp.write("              ....,,.,   .,,.,- .   .,,, ,,,,~              "+"\n")
    fp.write("               .....,. .,,...,~.    ,,,,--,,,,.             "+"\n")
    fp.write("               ....., ..,,,,,,.,  .,,,-,,,,,,,-             "+"\n")
    fp.write("               ........, ...  .------,,,,,,,,,-             "+"\n")
    fp.write("               ....... .,.    .,,,,.-,,,,,,-,-,             "+"\n")
    fp.close()
    
def x2():
    print("                                                            "+"\n")
    print("       ,=#~        .                                        "+"\n")
    print("     ?  ~X?-      ...                                       "+"\n")
    print("     ?.-*^^      .,~--.                      ,,             "+"\n")
    print("   ,-=  ~^       .-.~~,,..                 ,,--             "+"\n")
    print("     *^ ,?       ,,.,.~-,,,-,,,-******~-,,,-~~~             "+"\n")
    print("     -?    .,^.  .,,,~-,,--,,,,,--~****~--~~~~-             "+"\n")
    print("      .  ,.*^.    .~,,,,,,------,~--~***~*-,~~.             "+"\n")
    print("           >-     ..,,,-~***~****-*~~^*~**~--               "+"\n")
    print("           .,     .,-,,~*~*,~~**~***^-**~~~,                "+"\n")
    print("         ?*      .,~--***~,,~~~~~~~~~-**-**~                "+"\n")
    print("         -=,    .,-^~**>~^>^~,-~~*~-.,~*-***.               "+"\n")
    print("       .-=X     ,-,^*~~........,,.~>=X?*~***,               "+"\n")
    print("     -, ~,^=   ..-,,~-,.... .. .....,--=**^-                "+"\n")
    print("       -^ .#,..-~,-,~~....,>===>>,....,~~*^,    ..          "+"\n")
    print("       *.    .,,,,--^-...-^^^^>^=>....-~~~*~.  .,-,-.       "+"\n")
    print("      .   >-,.,,,,~^^^^..-,^^^*^*~...,^^,~~- ..,,,,,--      "+"\n")
    print("          ~?.,,,**^^^^^^...-.---....~^^^^-~~.  .,,,,,~-     "+"\n")
    print("         .,#~~-~*^^^*^>^>**......-^^^^^^^--*~   .-,,,---    "+"\n")
    print("        ,.--=-~~^**~**^>^,*^^*^^=>X^*^***^,~~.   -~-,,,~,   "+"\n")
    print("       .,~**?*-~**^*^~*>,,,-,-,-~?#*^****^--*~,   -,,,,,-   "+"\n")
    print("       ,*^^*-#.~,,-^,.,=-,,*=*^#X#=,,~**^*~,*^~.  -,,,,,~   "+"\n")
    print("      -*~^**^*#,. .~...-?==#=>XX=,-,,,,,,**,*^*,   .,,,,~   "+"\n")
    print("     ,,~~***~~.~.  ,,,,..-*^*,,...,.....--~-^**-.  ,,,,-^   "+"\n")
    print("    .,-,~****,,~,.   -..,~~~*,...........--****~, .,,,--*   "+"\n")
    print("     -.,~~**~,,*,,     .,,---............*-**~*~,  ,,,,--   "+"\n")
    print("     , ,,*~~*-,-~.          ,,.........--~*~*-*-- ,,,,,-,   "+"\n")
    print("     . .,-~~-, ,,~,.           . ......~*~~~~---  ,,,,,~.   "+"\n")
    print("         ,-~,. .,.*^ ...          ....,,,--.. .  .,,,,-~    "+"\n")
    print("            . , ,-*~^-^^^,,.  .         ,,.      ,,,,,~.    "+"\n")
    print("           .   ..,.*~-*-~^^~-.,.     ....,      .,,,,~-     "+"\n")
    print("           .   .,-.->~~~~>-,>*? ,    ,.,,-     .,,,,-~.     "+"\n")
    print("           ,   ,,,,,,>*,,*-X.,~,,   ..  .-    ..,-~~~,      "+"\n")
    print("            ...,,.- . .~~*~^,^ -.        ,. .,-~****,       "+"\n")
    print("              -,,,,.., ..., -  -      .. ,~~***~***.        "+"\n")
    print("              ,,--,- ,.  ,,  ..-      ,, .~*****^,          "+"\n")
    print("              ..,,,,, ..  ,, .,.     ,,, ,,~^^^,            "+"\n")
    print("              ....,,.,   .,,.,- .   .,,, ,,,,~              "+"\n")
    print("               .....,. .,,...,~.    ,,,,--,,,,.             "+"\n")
    print("               ....., ..,,,,,,.,  .,,,-,,,,,,,-             "+"\n")
    print("               ........, ...  .------,,,,,,,,,-             "+"\n")
    print("               ....... .,.    .,,,,.-,,,,,,-,-,             "+"\n")
cc=input("+:1 記事本  -:2 Python印出")
if cc=="1":
    x()
    print("建立完成!!!")
elif cc=="2":
    x2()
# Out:
# +:1 記事本  -:2 Python印出2
#
#
#        ,=#~        .
#
#      ?  ~X?-      ...
#
#      ?.-*^^      .,~--.                      ,,
#
#    ,-=  ~^       .-.~~,,..                 ,,--
#
#      *^ ,?       ,,.,.~-,,,-,,,-******~-,,,-~~~
#
#      -?    .,^.  .,,,~-,,--,,,,,--~****~--~~~~-
#
#       .  ,.*^.    .~,,,,,,------,~--~***~*-,~~.
#
#            >-     ..,,,-~***~****-*~~^*~**~--
#
#            .,     .,-,,~*~*,~~**~***^-**~~~,
#
#          ?*      .,~--***~,,~~~~~~~~~-**-**~
#
#          -=,    .,-^~**>~^>^~,-~~*~-.,~*-***.
#
#        .-=X     ,-,^*~~........,,.~>=X?*~***,
#
#      -, ~,^=   ..-,,~-,.... .. .....,--=**^-
#
#        -^ .#,..-~,-,~~....,>===>>,....,~~*^,    ..
#
#        *.    .,,,,--^-...-^^^^>^=>....-~~~*~.  .,-,-.
#
#       .   >-,.,,,,~^^^^..-,^^^*^*~...,^^,~~- ..,,,,,--
#
#           ~?.,,,**^^^^^^...-.---....~^^^^-~~.  .,,,,,~-
#
#          .,#~~-~*^^^*^>^>**......-^^^^^^^--*~   .-,,,---
#
#         ,.--=-~~^**~**^>^,*^^*^^=>X^*^***^,~~.   -~-,,,~,
#
# ...
